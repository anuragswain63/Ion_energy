# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
pd.options.display.float_format = '{:.2f}'.format
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime

# %%
ion_db=pd.read_excel("Assignment_file_for_Data _Analyst.XLSX")

# %%
ion_db.shape
# Out:
# (31104, 12)

# %%
(ion_db.isnull().sum())*100/len(ion_db)
# Out:
# Timestamp                            0.00
# Current                              0.00
# Total voltage                        0.00
# SOC                                  0.00
# Temperature                          0.00
# SOH                                  0.00
# Equivalent cycle                     0.00
# Application status                   0.00
# Grid status                          0.00
# Grid power                           0.00
# Grid energy consumption              0.00
# Grid cumulative energy consumption   0.00
# dtype: float64

# %%
ion_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31104 entries, 0 to 31103
# Data columns (total 12 columns):
# Timestamp                             31104 non-null int64
# Current                               31104 non-null int64
# Total voltage                         31104 non-null float64
# SOC                                   31104 non-null float64
# Temperature                           31104 non-null float64
# SOH                                   31104 non-null float64
# Equivalent cycle                      31104 non-null float64
# Application status                    31104 non-null int64
# Grid status                           31104 non-null int64
# Grid power                            31104 non-null float64
# Grid energy consumption               31104 non-null float64
# Grid cumulative energy consumption    31104 non-null float64
# dtypes: float64(8), int64(4)
# memory usage: 2.8 MB

# %%
ion_db.head()
# Out:
#        Timestamp  Current  Total voltage  SOC  Temperature  SOH  \
# 0  1556701215000        0          66.72 1.00        25.23 1.00
# 1  1556702215000        0          66.72 1.00        25.53 1.00
# 2  1556703215000        0          66.72 1.00        25.86 1.00
# 3  1556704215000        0          66.72 1.00        26.20 1.00
# 4  1556705215000        0          66.72 1.00        26.55 1.00
#
#    Equivalent cycle  Application status  Grid status  Grid power  \
# 0              0.00                   1            1        0.00
# 1              0.00                   1            1        0.00
# 2              0.00                   1            1        0.00
# 3              0.00                   1            1        0.00
# 4              0.00                   1            1        0.00
#
#    Grid energy consumption  Grid cumulative energy consumption
# 0                     0.00                                0.00
# ...

# %%
ion_db['Timestamp_datetime']=pd.to_datetime(ion_db['Timestamp'],unit='ms')

# %%
ion_db.head()
# Out:
#        Timestamp  Current  Total voltage  SOC  Temperature  SOH  \
# 0  1556701215000        0          66.72 1.00        25.23 1.00
# 1  1556702215000        0          66.72 1.00        25.53 1.00
# 2  1556703215000        0          66.72 1.00        25.86 1.00
# 3  1556704215000        0          66.72 1.00        26.20 1.00
# 4  1556705215000        0          66.72 1.00        26.55 1.00
#
#    Equivalent cycle  Application status  Grid status  Grid power  \
# 0              0.00                   1            1        0.00
# 1              0.00                   1            1        0.00
# 2              0.00                   1            1        0.00
# 3              0.00                   1            1        0.00
# 4              0.00                   1            1        0.00
#
#    Grid energy consumption  Grid cumulative energy consumption  \
# 0                     0.00                                0.00
# ...

# %%
ion_db['date']=ion_db['Timestamp_datetime'].dt.date

# %%
ion_db['time']=ion_db['Timestamp_datetime'].dt.time

# %%
ion_db.head()
# Out:
#        Timestamp  Current  Total voltage  SOC  Temperature  SOH  \
# 0  1556701215000        0          66.72 1.00        25.23 1.00
# 1  1556702215000        0          66.72 1.00        25.53 1.00
# 2  1556703215000        0          66.72 1.00        25.86 1.00
# 3  1556704215000        0          66.72 1.00        26.20 1.00
# 4  1556705215000        0          66.72 1.00        26.55 1.00
#
#    Equivalent cycle  Application status  Grid status  Grid power  \
# 0              0.00                   1            1        0.00
# 1              0.00                   1            1        0.00
# 2              0.00                   1            1        0.00
# 3              0.00                   1            1        0.00
# 4              0.00                   1            1        0.00
#
#    Grid energy consumption  Grid cumulative energy consumption  \
# 0                     0.00                                0.00
# ...

# %%
ion_db['date'].value_counts()
# Out:
# 2019-11-13    87
# 2019-05-22    87
# 2019-07-23    87
# 2019-06-08    87
# 2019-08-22    87
# 2019-12-08    87
# 2019-11-08    87
# 2019-12-28    87
# 2019-09-04    87
# 2020-03-19    87
# 2019-06-03    87
# 2019-05-27    87
# 2020-01-09    87
# 2019-11-23    87
# 2020-01-19    87
# 2019-05-09    87
# 2019-08-30    87
# 2020-04-03    87
# 2019-10-21    87
# 2019-09-26    87
# 2019-08-25    87
# 2019-12-18    87
# 2019-09-24    87
# 2020-01-22    87
# 2020-04-16    87
# 2019-05-17    87
# 2020-04-13    87
# 2019-12-15    87
# 2019-09-06    87
# 2019-11-05    87
#               ..
# 2019-08-19    86
# 2019-08-13    86
# 2019-10-23    86
# 2019-08-14    86
# 2019-10-18    86
# 2019-12-29    86
# 2019-09-05    86
# 2019-08-24    86
# 2019-12-04    86
# 2019-12-24    86
# 2019-07-24    86
# 2020-01-23    86
# 2019-07-04    86
# 2019-12-17    86
# 2020-02-05    86
# 2019-06-29    86
# 2020-01-26    86
# 2020-03-16    86
# 2019-06-09    86
# 2019-07-15    86
# 2020-03-10    86
# ...

# %%
ion_db['year']=ion_db['Timestamp_datetime'].dt.year
ion_db['month']=ion_db['Timestamp_datetime'].dt.month

# %%
ion_db.head()
# Out:
#        Timestamp  Current  Total voltage  SOC  Temperature  SOH  \
# 0  1556701215000        0          66.72 1.00        25.23 1.00
# 1  1556702215000        0          66.72 1.00        25.53 1.00
# 2  1556703215000        0          66.72 1.00        25.86 1.00
# 3  1556704215000        0          66.72 1.00        26.20 1.00
# 4  1556705215000        0          66.72 1.00        26.55 1.00
#
#    Equivalent cycle  Application status  Grid status  Grid power  \
# 0              0.00                   1            1        0.00
# 1              0.00                   1            1        0.00
# 2              0.00                   1            1        0.00
# 3              0.00                   1            1        0.00
# 4              0.00                   1            1        0.00
#
#    Grid energy consumption  Grid cumulative energy consumption  \
# 0                     0.00                                0.00
# ...

# %%
ion_db.tail()
# Out:
#            Timestamp  Current  Total voltage  SOC  Temperature  SOH  \
# 31099  1587800215000       10          64.97 0.88        23.57 0.92
# 31100  1587801215000       10          65.10 0.89        23.91 0.92
# 31101  1587802215000       10          65.22 0.90        24.25 0.92
# 31102  1587803215000       10          65.35 0.91        24.60 0.92
# 31103  1587804215000        0          65.36 0.91        24.84 0.92
#
#        Equivalent cycle  Application status  Grid status  Grid power  \
# 31099            107.83                   1            1      649.72
# 31100            107.84                   1            1      650.97
# 31101            107.84                   1            1      652.21
# 31102            107.85                   1            1      653.45
# 31103            107.85                   1            1        0.00
#
#        Grid energy consumption  Grid cumulative energy consumption  \
# 31099                   180.48                          1913169.64
# ...

# %%
ion_db['year'].value_counts()
# Out:
# 2019    21136
# 2020     9968
# Name: year, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Timestamp_datetime',y='SOC',data=ion_db)

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Timestamp_datetime',y='Grid status',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Timestamp_datetime',y='SOH',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Timestamp_datetime',y='SOC',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Timestamp_datetime',y='Temperature',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x='Timestamp_datetime',y='Equivalent cycle',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='SOC',y='Temperature',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
ion_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31104 entries, 0 to 31103
# Data columns (total 17 columns):
# Timestamp                             31104 non-null int64
# Current                               31104 non-null int64
# Total voltage                         31104 non-null float64
# SOC                                   31104 non-null float64
# Temperature                           31104 non-null float64
# SOH                                   31104 non-null float64
# Equivalent cycle                      31104 non-null float64
# Application status                    31104 non-null int64
# Grid status                           31104 non-null int64
# Grid power                            31104 non-null float64
# Grid energy consumption               31104 non-null float64
# Grid cumulative energy consumption    31104 non-null float64
# Timestamp_datetime                    31104 non-null datetime64[ns]
# date                                  31104 non-null object
# ...

# %%
ion_db['Grid status'].value_counts()
# Out:
# 1    30735
# 0      369
# Name: Grid status, dtype: int64

# %%
sns.scatterplot(x='Grid status',y='SOC',data=ion_db)

# %%
sns.scatterplot(x='Equivalent cycle',y='SOH',data=ion_db)

# %%
sns.lineplot(x='Timestamp_datetime',y='Equivalent cycle',data=ion_db)

# %%
sns.lineplot(x='Timestamp_datetime',y='SOH',data=ion_db)

# %%
sns.scatterplot(x='SOC',y='Temperature',data=ion_db)

# %%
sns.scatterplot(x='Grid status',y='Temperature',data=ion_db)

# %%
sns.scatterplot(x='Grid status',y='SOC',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
sns.scatterplot(x='Grid status',y='SOC',data=ion_db.loc[ion_db['date'].astype(str)=='2019-05-02'])

# %%
sns.scatterplot(x='SOC',y='Temperature',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
sns.scatterplot(x='SOC',y='Temperature',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==10)])

# %%
sns.scatterplot(x='SOC',y='Temperature',data=ion_db.loc[(ion_db['year']==2020)&(ion_db['month']==4)])

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='Grid status',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='SOC',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='SOH',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='Temperature',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='Equivalent cycle',data=ion_db.loc[(ion_db['year']==2019)&(ion_db['month']==5)])

# %%
print(ion_db['Equivalent cycle'].max())
print(ion_db['Equivalent cycle'].min())
# Out:
# 107.8477185
# 0.0

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='SOC',data=ion_db,hue='Grid status')

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Timestamp_datetime',y='SOC',data=ion_db,hue='Grid status')

# %%
ion_db['Grid status'].corr(ion_db['SOC'])
# Out:
# 0.22794666128547864

# %%
ion_db['Equivalent cycle'].corr(ion_db['SOH'])
# Out:
# -0.9842624478536399

# %%
ion_db['SOC'].corr(ion_db['Temperature'])
# Out:
# -0.36904035326610585

# %%
ion_db['SOH'].corr(ion_db['Temperature'])
# Out:
# 0.003683839886595986

# %%
ion_db['Grid status'].corr(ion_db['Temperature'])
# Out:
# -0.8450263318531464

# %%
ion_db['Grid status'].corr(ion_db['SOH'])
# Out:
# 0.003189553114862735

# %%
ion_db.corr()
# Out:
#                                     Timestamp  Current  Total voltage   SOC  \
# Timestamp                                1.00     0.00          -0.05 -0.05
# Current                                  0.00     1.00           0.08  0.12
# Total voltage                           -0.05     0.08           1.00  1.00
# SOC                                     -0.05     0.12           1.00  1.00
# Temperature                             -0.00    -0.82          -0.33 -0.37
# SOH                                     -0.99    -0.00           0.05  0.05
# Equivalent cycle                         1.00     0.00          -0.05 -0.05
# Application status                      -0.01    -0.00           0.05  0.04
# Grid status                             -0.00     0.99           0.18  0.23
# Grid power                               0.02     0.22          -0.67 -0.67
# Grid energy consumption                  0.02     0.22          -0.67 -0.67
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(ion_db[ion_db.columns.difference(['Timestamp','year','month'])].corr(),annot=True,cmap='coolwarm')
